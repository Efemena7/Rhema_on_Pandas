# %%
import pandas as pd

# %%
data = pd.read_csv("drinks2.csv")

# %%
data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
data1=data.set_index(["continent","country"])

# %%
data1
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# continent country
# AS        Afghanistan              0                0              0
# EU        Albania                 89              132             54
# AF        Algeria                 25                0             14
# EU        Andorra                245              138            312
# AF        Angola                 217               57             45
# ...                              ...              ...            ...
# SA        Venezuela              333              100              3
# AS        Vietnam                111                2              1
#           Yemen                    6                0              0
# AF        Zambia                  32               19              4
#           Zimbabwe                64               18              4
#
#                        total_litres_of_pure_alcohol
# continent country
# ...

# %%
data1.sort_index()
# Out:
#                                         beer_servings  spirit_servings  \
# continent country
# AF        Algeria                                  25                0
#           Angola                                  217               57
#           Benin                                    34                4
#           Botswana                                173               35
#           Burkina Faso                             25                7
# ...                                               ...              ...
# NaN       St. Kitts & Nevis                       194              205
#           St. Lucia                               171              315
#           St. Vincent & the Grenadines            120              221
#           Trinidad & Tobago                       197              156
#           USA                                     249              158
#
#                                         wine_servings  \
# continent country
# ...

# %%
data2=data1.sort_index()

# %%
data2
# Out:
#                                         beer_servings  spirit_servings  \
# continent country
# AF        Algeria                                  25                0
#           Angola                                  217               57
#           Benin                                    34                4
#           Botswana                                173               35
#           Burkina Faso                             25                7
# ...                                               ...              ...
# NaN       St. Kitts & Nevis                       194              205
#           St. Lucia                               171              315
#           St. Vincent & the Grenadines            120              221
#           Trinidad & Tobago                       197              156
#           USA                                     249              158
#
#                                         wine_servings  \
# continent country
# ...

# %% [markdown]
# # DESCENDIND

# %% [markdown]
# ## Wine seriving

# %%
data2.sort_values("wine_servings",ascending=False)
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# continent country
# EU        France                 127              151            370
#           Portugal               194               67            339
#           Andorra                245              138            312
#           Switzerland            185              100            280
#           Denmark                224               81            278
# ...                              ...              ...            ...
# AS        Maldives                 0                0              0
#           Myanmar                  5                1              0
#           Nepal                    5                6              0
# AF        Ethiopia                20                3              0
# AS        Yemen                    6                0              0
#
#                        total_litres_of_pure_alcohol
# continent country
# ...

# %%
data2.sort_values("wine_servings",ascending=False).head(20)
# Out:
#                              beer_servings  spirit_servings  wine_servings  \
# continent country
# EU        France                       127              151            370
#           Portugal                     194               67            339
#           Andorra                      245              138            312
#           Switzerland                  185              100            280
#           Denmark                      224               81            278
#           Slovenia                     270               51            276
#           Luxembourg                   236              133            271
#           Croatia                      230               87            254
#           Italy                         85               42            237
# AF        Equatorial Guinea             92                0            233
# SA        Argentina                    193               25            221
# ...

# %% [markdown]
# ## spirit servings

# %%
data2.sort_values("spirit_servings",ascending=False).head(20)
# Out:
#                                         beer_servings  spirit_servings  \
# continent country
# NaN       Grenada                                 199              438
# EU        Belarus                                 142              373
# NaN       Haiti                                     1              326
# AS        Russian Federation                      247              326
# NaN       St. Lucia                               171              315
# SA        Guyana                                   93              302
# EU        Slovakia                                196              293
# NaN       Dominica                                 52              286
# AS        Thailand                                 99              258
# OC        Cook Islands                              0              254
# EU        Bulgaria                                231              252
# AS        Kazakhstan                              124              246
# ...

# %%
data2.sort_values("spirit_servings",ascending=False)
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# continent country
# NaN       Grenada                       199              438             28
# EU        Belarus                       142              373             42
# NaN       Haiti                           1              326              1
# AS        Russian Federation            247              326             73
# NaN       St. Lucia                     171              315             71
# ...                                     ...              ...            ...
# AS        North Korea                     0                0              0
#           Pakistan                        0                0              0
# EU        Monaco                          0                0              0
#           San Marino                      0                0              0
# AS        Yemen                           6                0              0
#
# ...

# %% [markdown]
# ## Total liters of pure alcohol

# %%
data2.sort_values("total_litres_of_pure_alcohol",ascending=False)
# Out:
#                             beer_servings  spirit_servings  wine_servings  \
# continent country
# EU        Belarus                     142              373             42
#           Lithuania                   343              244             56
#           Andorra                     245              138            312
# NaN       Grenada                     199              438             28
# EU        Czech Republic              361              170            134
# ...                                   ...              ...            ...
# AS        Kuwait                        0                0              0
#           Iran                          0                0              0
# AF        Somalia                       0                0              0
# AS        Afghanistan                   0                0              0
# OC        Marshall Islands              0                0              0
#
#                             total_litres_of_pure_alcohol
# ...

# %%
data2.sort_values("total_litres_of_pure_alcohol",ascending=False).head(20)
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# continent country
# EU        Belarus                       142              373             42
#           Lithuania                     343              244             56
#           Andorra                       245              138            312
# NaN       Grenada                       199              438             28
# EU        Czech Republic                361              170            134
#           France                        127              151            370
# AS        Russian Federation            247              326             73
# EU        Ireland                       313              118            165
#           Luxembourg                    236              133            271
#           Slovakia                      196              293            116
#           Germany                       346              117            175
# ...

# %% [markdown]
# # ASCENDING

# %%
mask=data2["wine_servings"]!=0
mask1=data2["spirit_servings"]!=0
mask2=data2["total_litres_of_pure_alcohol"]!=0

# %% [markdown]
# ## Wine servings

# %%
data3=data2[mask].sort_values("wine_servings")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4808\3929718936.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data3=data2[mask].sort_values("wine_servings")

# %%
data3
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# continent country
# AS        Oman                    22               16              1
#           Thailand                99              258              1
# AF        Tanzania                36                6              1
# AS        Philippines             71              186              1
#           Jordan                   6               21              1
# ...                              ...              ...            ...
# EU        Denmark                224               81            278
#           Switzerland            185              100            280
#           Andorra                245              138            312
#           Portugal               194               67            339
#           France                 127              151            370
#
#                        total_litres_of_pure_alcohol
# continent country
# ...

# %%
data3.head(40)
# Out:
#                                     beer_servings  spirit_servings  \
# continent country
# AS        Oman                                 22               16
#           Thailand                             99              258
# AF        Tanzania                             36                6
# AS        Philippines                          71              186
#           Jordan                                6               21
# AF        Egypt                                 6                4
# NaN       Nicaragua                            78              118
# AF        Comoros                               1                3
#           Namibia                             376                3
# AS        Cambodia                             57               65
# AF        Malawi                                8               11
#           Niger                                 3                2
#           DR Congo                             32                3
# ...

# %% [markdown]
# ## Spirit serving

# %%
data4=data2[mask1].sort_values("spirit_servings")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4808\1269058032.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data4=data2[mask1].sort_values("spirit_servings")

# %%
data4
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# continent country
# AF        Cote d'Ivoire                  37                1              7
#           Chad                           15                1              1
#           Senegal                         9                1              7
#           Mali                            5                1              1
# AS        Timor-Leste                     1                1              4
# ...                                     ...              ...            ...
# NaN       St. Lucia                     171              315             71
# AS        Russian Federation            247              326             73
# NaN       Haiti                           1              326              1
# EU        Belarus                       142              373             42
# NaN       Grenada                       199              438             28
#
# ...

# %%
data4.head(40)
# Out:
#                                     beer_servings  spirit_servings  \
# continent country
# AF        Cote d'Ivoire                        37                1
#           Chad                                 15                1
#           Senegal                               9                1
#           Mali                                  5                1
# AS        Timor-Leste                           1                1
# AF        Congo                                76                1
#           Cameroon                            147                1
#           Niger                                 3                2
#           Togo                                 36                2
# AS        Brunei                               31                2
# AF        Central African Republic             17                2
# AS        Vietnam                             111                2
# AF        Swaziland                            90                2
# ...

# %% [markdown]
# ## total litres of pure alcohol

# %%
data5=data2[mask2].sort_values("total_litres_of_pure_alcohol")

# %%
data5
# Out:
#                           beer_servings  spirit_servings  wine_servings  \
# continent country
# AS        Indonesia                   5                1              0
#           Yemen                       6                0              0
# AF        Niger                       3                2              1
# AS        Saudi Arabia                0                5              0
#           Myanmar                     5                1              0
# ...                                 ...              ...            ...
# EU        Czech Republic            361              170            134
# NaN       Grenada                   199              438             28
# EU        Andorra                   245              138            312
#           Lithuania                 343              244             56
#           Belarus                   142              373             42
#
#                           total_litres_of_pure_alcohol
# continent country
# ...

# %%
data5.head(40)
# Out:
#                            beer_servings  spirit_servings  wine_servings  \
# continent country
# AS        Indonesia                    5                1              0
#           Yemen                        6                0              0
# AF        Niger                        3                2              1
# AS        Saudi Arabia                 0                5              0
#           Myanmar                      5                1              0
#           Timor-Leste                  1                1              4
# AF        Comoros                      1                3              1
# AS        Nepal                        5                6              0
# AF        Egypt                        6                4              1
#           Guinea                       9                0              2
# AS        Iraq                         9                3              0
#           Tajikistan                   2               15              0
# ...

# %%
data2
# Out:
#                                         beer_servings  spirit_servings  \
# continent country
# AF        Algeria                                  25                0
#           Angola                                  217               57
#           Benin                                    34                4
#           Botswana                                173               35
#           Burkina Faso                             25                7
# ...                                               ...              ...
# NaN       St. Kitts & Nevis                       194              205
#           St. Lucia                               171              315
#           St. Vincent & the Grenadines            120              221
#           Trinidad & Tobago                       197              156
#           USA                                     249              158
#
#                                         wine_servings  \
# continent country
# ...
